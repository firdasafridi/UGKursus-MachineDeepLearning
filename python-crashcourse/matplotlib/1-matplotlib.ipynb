# %% [markdown]
# # Matplotlib Overview Lecture

# %% [markdown]
# ## Pendahuluan
#
# Matplotlib merupakan "bapak" library dari visualisasi data menggunakan Python. Dibuat oleh John Hunter. Ia membuatnya dalam percobaan untuk mereplika kemampuan plotting Matlab (atau beberapa bahasa pemrograman yang lain) ke dalam Python. Jadi jika kalian telah familiar dengan matlab, matplotlib akan sangat mudah buat kalian.
#
#
# Matplotlib mengijinkan kita untuk membuat grafik-grafik yang dapat direproduksi secara program. Untuk informasi library lebih lanjut, kunjungi official Matplotlib web page: http://matplotlib.org/
#
# ___
#
#
# ## Importing

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Khusus untuk programming di jupyter notebook, kita juga membutuhkan satu line berikut. Mengijinkan kita untuk melakukan "pencetakan gambar" pada lembar notebook. Jika kalian melakukan programming di IDE lain, baris ini tidak diperlukan.

# %%
# %matplotlib inline

# %% [markdown]
# # Menggunakan Matplotlib menggunakan Fungsi
#
# Mari mulai dari contoh yang paling sederhana. Kita akan men-generate beberapa nilai ke dua buah variable x dan y menggunakan numpy array. Kita juga bisa menggunakan Python list, namun kita akan lebih sering menggunakan numpy array.

# %%
import numpy as np
x = np.linspace(0, 5, 11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %% [markdown]
# ## Membuat Singleplot Sederhana
#
# Kita bisa membuat grafik garis yang sangat sederhana yang melakukan plot variable x dan y kita dengan cara-cara berikut.

# %%
plt.plot(x, y, 'r') # 'r' is the color red
plt.xlabel('X Axis Title Here')
plt.ylabel('Y Axis Title Here')
plt.title('String Title Here')
plt.show()

# %% [markdown]
# ## Membuat Multiplot Sederhana

# %%
# plt.subplot(nrows, ncols, plot_number)
plt.subplot(1,2,1)
plt.plot(x, y, 'r--')
plt.subplot(1,2,2)
plt.plot(y, x, 'g*-');

# %% [markdown]
# ___
# # Matplotlib Object Oriented Method
#
# Kita telah melihat cara membuat plot menggunakan matplotlib dengan menggunakan fungsi-fungsi. Kita akan melakukannya ulang, nemun dengan cara yang lebih formal, yakni menggunakan Matplotlib's Object Oriented API. Ini artinya kita akan melakukan instatiate object "figure" dan kemudian memanggil method-methodnya dari objek tersebut.

# %% [markdown]
# ## Membuat figure dengan Plot Manual

# %%
# Buat objek figure (canvas kosong)
fig = plt.figure()

# buat dan tetapkan axis untuk figure tersebut
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # left, bottom, width, height (range 0 to 1)

# plot nilai2 kita kedalam axis
axes.plot(x, y, 'b')
axes.set_xlabel('Set X Label')
axes.set_ylabel('Set y Label')
axes.set_title('Set Title')

# %% [markdown]
# Kodingnya terlihat lebih kompleks, tapi keuntungannya adalah kita bisa memiliki kontrol secara penuh untuk menaruh dimana letak plot kita, dan kita juga bisa dengan mudah menambahkan axis-axis lainnya kedalam figure.

# %%
# Creates blank canvas
fig = plt.figure()

axes1 = fig.add_axes([0, 0, 0.8, 0.8]) # main axes
axes2 = fig.add_axes([0.1, 0.4, 0.4, 0.3]) # inset axes

# Larger Figure Axes 1
axes1.plot(x, y, 'b')
axes1.set_xlabel('X_label_axes2')
axes1.set_ylabel('Y_label_axes2')
axes1.set_title('Axes 2 Title')

# Insert Figure Axes 2
axes2.plot(y, x, 'r')
axes2.set_xlabel('X_label_axes2')
axes2.set_ylabel('Y_label_axes2')
axes2.set_title('Axes 2 Title');

# %% [markdown]
# ## Membuat figure dengan Plot Otomatis (subplot)
#
# Obbjek plt.subplots() akan melakukan manajerial axis-axis kita secara otomatis. kita tidak perlu menetapkan range dan posisi axis kita, biarkan Objek plt.subplots() yang melakukannya.

# %%
# Serupa dengan object plt.figure(), jika kita menggunakan plt.subplots(), kita mendapatkan tuple figure dan axis
fig, axes = plt.subplots()

# gunakan axes untuk plotting data-data kita
axes.plot(x, y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title');

# %% [markdown]
# Kita juga bisa menspesifikasikan jumlah dari baris dan kolom ketika kita membuat objek subplot()

# %%
# kavas kosong dengan 1x2 subplot
fig, axes = plt.subplots(nrows=1, ncols=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f3bdb7fe319e> in <module>()
#       1 # kavas kosong dengan 1x2 subplot
# ----> 2 fig, axes = plt.subplots(nrows=1, ncols=2)
#
# NameError: name 'plt' is not defined

# %%
# Jika penasaran axes itu isinya apa, coba kita tampilkan.
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f53b5f0a3c8>,
# ...
#       dtype=object)

# %% [markdown]
# Kita bisa lihat bahwa axes merupakan sebuah array. Itu tandanya kita bisa melakukan iterasi untuk seluruh axes yang ada.

# %%
for ax in axes:
    ax.plot(x, y, 'b')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('title')

# tampilkan figure  
fig

# %% [markdown]
# Sebuah permasalahan yang umum ditemui menggunakan subplot atau figures adalah adanya overlapping antar axes. Kita bisa gunakan method **fig.tight_layout()** atau **plt.tight_layout()**. Method ini akan melakukan pengaturan posisi secara otomatis sehingga tidak ada overlapping lagi antar axes.

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

for ax in axes:
    ax.plot(x, y, 'g')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_title('title')

fig    
plt.tight_layout()

# %% [markdown]
# ## Figure size

# %% [markdown]
# Matplotlib juga mengijinkan kita untuk mengubah ukuran plot kita seperti berikut.

# %%
fig, axes = plt.subplots(figsize=(12,3))

axes.plot(x, y, 'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title');

# %% [markdown]
# ## Menyimpan Gambar
#
# Matplotlib dapat men-generate output yang HQ dalam beragam extensi seperti PNG, JPG, EPS, SVG, PGF and PDF.

# %%
fig.savefig("filename.png")

# %%
fig.savefig("filename.png", dpi=200)

# %% [markdown]
# ____
# ## Legends, Labels, dan Titles

# %% [markdown]
# Sekarang kita telah memahami beberapa dasar plotting menggunakan matplotlib. Sekarang kita akan coba melakukan dekorasi plot kita, seperti menambahkan judul, label axis, dan legenda.

# %% [markdown]
# ### Judul Plot

# %%
ax.set_title("title");

# %% [markdown]
# ### Label Axis

# %%
ax.set_xlabel("x")
ax.set_ylabel("y");

# %% [markdown]
# ### Legends
#
# Kita bisa menggunakan parameter **label="label text"** saat melakukan plotting, kemudian memanggil fungsi legend di akhir snippet code

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

ax.plot(x, x**2, label="x squared")
ax.plot(x, x**3, label="x cube")
ax.legend()

# %% [markdown]
# Legend bisa ditaruh ditempat-tempat tertentu dalam grafik kita dengan menambakan parameter 'loc' dalam fungsi legend. 'loc' menerima numerical code dari 1-9, detail dari makna angka-angka tersebut bisa dilihat di [documentation page](http://matplotlib.org/users/legend_guide.html#legend-location)

# %%
ax.legend(loc=1) # pojok kanan atas
ax.legend(loc=2) # pojok kiri atas
ax.legend(loc=3) # pojok kiri bawah
ax.legend(loc=4) # pojok kanan bawah

# Yang biasa digunakan
ax.legend(loc=0) # biarkan matplotlib mencari posisi yang terbaik
fig
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-845cf0a46eff> in <module>()
# ----> 1 ax.legend(loc=1) # pojok kanan atas
#       2 ax.legend(loc=2) # pojok kiri atas
#       3 ax.legend(loc=3) # pojok kiri bawah
#       4 ax.legend(loc=4) # pojok kanan bawah
#       5
#
# NameError: name 'ax' is not defined

# %% [markdown]
# ## Setting colors, linewidths, linetypes
#
# Matplot lib memberikan kita banyak sekali opsi untuk melakukan kostumisasi warna, besar garis, tipe garis. Seluruh syntaxnya serupa dengan MATLAB.

# %% [markdown]
# ### Kostumisasi Warna seperti MATLAB

# %%
fig, ax = plt.subplots()
ax.plot(x, x**2, 'b.-') # blue line with dots
ax.plot(x, x**3, 'g--') # green dashed line

# %% [markdown]
# ### Kostumisasi Warna Menggunakan Keyword dan RGB hex code

# %%
fig, ax = plt.subplots()

ax.plot(x, x+1, color="blue", alpha=0.5) # half-transparant
ax.plot(x, x+2, color="#8B008B")        # RGB hex code
ax.plot(x, x+3, color="#FF8C00")        # RGB hex code

# %% [markdown]
# ### Kostumisasi Garis dan Style Marker

# %%
fig = plt.figure()

ax = fig.add_axes([0,0,1,1])

#ax.plot(x,y, color='purple', linewidth=3, linestyle='--', marker='o', markersize=15, markerfacecolor='yellow', markeredgewidth=3, markeredgecolor='green')

# %% [markdown]
# ### Parameter Kostumisasi Secara Lengkap

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+1, color="red", linewidth=0.25)
ax.plot(x, x+2, color="red", linewidth=0.50)
ax.plot(x, x+3, color="red", linewidth=1.00)
ax.plot(x, x+4, color="red", linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="green", lw=3, linestyle='-')
ax.plot(x, x+6, color="green", lw=3, ls='-.')
ax.plot(x, x+7, color="green", lw=3, ls=':')

# custom dash
line, = ax.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(x, x+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(x, x+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(x, x+12, color="blue", lw=3, ls='--', marker='1')

# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");

# %% [markdown]
# ___
# ## Plot range

# %% [markdown]
# Kita bisa melakukan konfigurasi rentang dari axis kita menggunakan method `set_ylim` dan `set_xlim` di objek axis. Atau, kita bisa gunakan `axis('tight')` untuk secara otomatis mendapatkan rentang yang "tightly fitted"

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes[0].plot(x, x**2, x, x**3)
axes[0].set_title("default axes ranges")

axes[1].plot(x, x**2, x, x**3)
axes[1].axis('tight')
axes[1].set_title("tight axes")

axes[2].plot(x, x**2, x, x**3)
axes[2].set_ylim([0, 60])
axes[2].set_xlim([2, 5])
axes[2].set_title("custom axes range");

# %% [markdown]
# ___
# # Plot Bertipe Khusus
# Matplotlib juga menyediakan beberapa plot khusus seperti barplots, histogram, scatter plots, dan lain-lain. Beberapa diantara plot-plot ini lebih nyaman digunakan menggunakan Seaborn, librari visualisasi lain yang ditujukan untuk data-data statistik. Meskipun demikin, kita bisa melihat aksi dari matplotlib sebagai berikut.

# %%
plt.scatter(x,y)

# %%
from random import sample
data = sample(range(1, 1000), 100)
plt.hist(data)
# Out:
# (array([10., 11., 10.,  6., 11., 10., 11., 14.,  7., 10.]),
#  array([  1.,  97., 193., 289., 385., 481., 577., 673., 769., 865., 961.]),
#  <a list of 10 Patch objects>)

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# rectangular box plot
plt.boxplot(data,vert=True,patch_artist=True);

# %% [markdown]
# ## Further reading

# %% [markdown]
# * http://www.matplotlib.org - The project web page for matplotlib.
# * https://github.com/matplotlib/matplotlib - The source code for matplotlib.
# * http://matplotlib.org/gallery.html - A large gallery showcaseing various types of plots matplotlib can create. Highly recommended!
# * http://www.loria.fr/~rougier/teaching/matplotlib - A good matplotlib tutorial.
# * http://scipy-lectures.github.io/matplotlib/matplotlib.html - Another good matplotlib reference.
